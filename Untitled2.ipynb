# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
#Optimized version
import numpy as np
import pandas as pd

# Generate a random input dataframe
np.random.seed(55)
df = pd.DataFrame({'x': np.random.rand(144)})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

import matplotlib.pyplot as plt

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes = np.abs(df['x'].values) * 200

plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()

magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()

# %%
for fibonacci in fibonacci_list:
    if fibonacci == 0:
        continue
    
    np.random.seed(fibonacci)
    df = pd.DataFrame({'x': np.random.rand(fibonacci)})

    X = np.fft.fft(df['x'].values)
    magnitude = np.abs(X)
    phase = np.angle(X)

    sizes = np.abs(df['x'].values) * 200

    plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5318033)
    plt.title(f"FFT of Dataframe with seed {fibonacci}")
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.colorbar()
    plt.show()
# Out:
# Traceback (most recent call last):
#   Input In [7] in <cell line: 1>
#     for fibonacci in fibonacci_list:
# NameError: name 'fibonacci_list' is not defined
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=NameError: name 'fibonacci_list' is not defined" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>
