# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft


def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        next_fib = fib_sequence[-1] + fib_sequence[-2]
        fib_sequence.append(next_fib)
    return fib_sequence

n = 333
fib_numbers = fibonacci(n)

# Generate a random array containing Fibonacci numbers
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the dataframe using scipy.fft
X = fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0.
'''
plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()
'''
magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.314)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()
#print(df.to_string())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft


def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        next_fib = fib_sequence[-1] + fib_sequence[-2] 
        fib_sequence.append(next_fib)
    return fib_sequence

n = 666
fib_numbers = fibonacci(n)

# Generate a random array containing Fibonacci numbers
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the dataframe using scipy.fft
X = fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0.
'''
plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()
'''
magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=1)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()
#print(df.to_string())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft


def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        next_fib = fib_sequence[-1] + fib_sequence[-2]
        fib_sequence.append(next_fib)
    return fib_sequence

n = 987
fib_numbers = fibonacci(n)

# Generate a random array containing Fibonacci numbers
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the dataframe using scipy.fft
X = fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0....
'''
plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()
'''
magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.314)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()
#print(df.to_string())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft


def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        next_fib = fib_sequence[-1] + fib_sequence[-2]
        fib_sequence.append(next_fib)
    return fib_sequence

n = 1400
fib_numbers = fibonacci(n)

# Generate a random array containing Fibonacci numbers
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the dataframe using scipy.fft
X = fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0....

plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()

magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()
#print(df.to_string())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft
from numba import njit

# Compile Fibonacci function with Numba
@njit
def fibonacci(n):
    fib_sequence = np.empty(n, dtype=np.int64)
    fib_sequence[0] = 0
    fib_sequence[1] = 1
    for i in range(2, n):
        fib_sequence[i] = fib_sequence[i-1] + fib_sequence[i-2]
    return fib_sequence
    return fib_sequence

# Generate Fibonacci sequence and randomize
n = 39088169
fib_numbers = fibonacci(n)
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the random Fibonacci numbers
X = fft(df['x'].values)

# Calculate magnitude and phase of FFT output
magnitude = np.abs(X)
phase = np.angle(X)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0.

# Plot the FFT output
plt.figure(figsize=(10, 8))
plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.314)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()

'''
plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()
'''
# Out:
# '\nplt.scatter(df.index, df[\'x\'], c=df[\'x\'], cmap=\'hsv\', s=sizes, alpha=0.5)\nplt.title("Input Dataframe")\nplt.xlabel("Index")\nplt.ylabel("Value")\nplt.colorbar()\nplt.show()\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft


def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        next_fib = fib_sequence[-1] + fib_sequence[-2] 
        fib_sequence.append(next_fib)
    return fib_sequence

n = 1444
fib_numbers = fibonacci(n)

# Generate a random array containing Fibonacci numbers
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the dataframe using scipy.fft
X = fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0....


magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()
#print(df.to_string())


plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()

# %%
#Optimized version
import numpy as np
import pandas as pd

# Generate a random input dataframe
np.random.seed(13)
df = pd.DataFrame({'x': np.random.rand(1444411)})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

import matplotlib.pyplot as plt

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes = np.abs(df['x'].values) * 1


plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()

magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()

# %%
#Optimized version
import numpy as np
import pandas as pd

# Generate a random input dataframe
np.random.seed(5555)
df = pd.DataFrame({'x': np.random.rand(5555)})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

import matplotlib.pyplot as plt

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes = np.abs(df['x'].values) * 1


plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.618033)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()

magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pygame

# Initialize Pygame
pygame.init()

# Set up the screen
screen_width = 800
screen_height = 600
screen = pygame.display.set_mode((screen_width, screen_height))
clock = pygame.time.Clock()

# Create a figure and axis object
fig, ax = plt.subplots()

# Define a function to update the plot with each frame of the animation
def update(frame):
    # Generate a random input dataframe
    df = pd.DataFrame({'x': np.random.rand(2**(frame+1))})

    # Calculate the FFT of the dataframe using numpy
    X = np.fft.fft(df['x'].values)

    # Define the size of each marker based on the magnitude of each element in the dataframe
    sizes = np.abs(df['x'].values) * 200

    # Clear the axis and plot the input dataframe using scatter plot
    ax.clear()
    ax.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5618033)
    ax.set_title("Input Dataframe (N={})".format(2**(frame+1)))
    ax.set_xlabel("Index")
    ax.set_ylabel("Value")
    ax.set_xlim(0, 2**(frame+1))
    ax.set_ylim(0, 1)
    ax.grid(True)

    # Calculate magnitude and phase of FFT output
    magnitude = np.abs(X)
    phase = np.angle(X)

    # Plot the FFT output using scatter plot
    ax.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5618033)
    ax.set_title("FFT of Dataframe (N={})".format(2**(frame+1)))
    ax.set_xlabel("Real Part")
    ax.set_ylabel("Imaginary Part")
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)
    ax.grid(True)

    # Save the plot to a temporary file
    plt.savefig('temp_plot.png')

    # Load the saved plot and display it in Pygame
    plot_surface = pygame.image.load('temp_plot.png').convert()
    plot_surface_rect = plot_surface.get_rect(center=(screen_width // 2, screen_height // 2))
    screen.fill((255, 255, 255))
    screen.blit(plot_surface, plot_surface_rect)
    pygame.display.flip()

    return ax

# Main loop
frame_count = 0
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    # Update the plot
    update(frame_count)
    frame_count += 1
    if frame_count == 10:  # Loop animation
        frame_count = 0

    clock.tick(2)  # Limit frame rate to 15 FPS

pygame.quit()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft
from numba import njit

# Compile Fibonacci function with Numba
@njit
def fibonacci(n):
    fib_sequence = np.empty(n, dtype=np.int64)
    fib_sequence[0] = 0
    fib_sequence[1] = 1
    for i in range(2, n):
        fib_sequence[i] = fib_sequence[i-1] + fib_sequence[i-2]
    return fib_sequence
    return fib_sequence

# Generate Fibonacci sequence and randomize
n = 5555
fib_numbers = fibonacci(n)
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the random Fibonacci numbers
X = fft(df['x'].values)

# Calculate magnitude and phase of FFT output
magnitude = np.abs(X)
phase = np.angle(X)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0.00000000000000000000000000000000000001618033988749894848204586834365638117720309179
# Plot the FFT output
plt.figure(figsize=(10, 8))
plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=1)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()


plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=1)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()
