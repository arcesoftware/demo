# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
import numpy as np

# Define the logarithmically averaged function
def f(a, g, h, x, m):
    sum = 0
    for n in range(int(x // m), int(x) + 1):
        prod = 1
        for k in range(len(g)):
            prod *= g[k](n + a * h[k])
        sum += prod
    return (1 / np.log(m)) * sum

# Define the values for the function inputs
g = [
    lambda n: np.sin(n),
    lambda n: np.cos(n),
    lambda n: np.tan(n)
]
h = [1, 2, 3]
x = 100
m = 1000

# Choose a value of a for the filter circuit
a = 2

# Create the quantum circuit for signal filtering
qreg = QuantumRegister(1)
creg = ClassicalRegister(1)
qc = QuantumCircuit(qreg, creg)

# Apply the logarithmically averaged filter
for n in range(int(x // m), int(x) + 1):
    qc.rz(f(a, g, h, n, m), qreg[0])

# Measure the filtered signal
qc.measure(qreg[0], creg[0])

# Simulate the circuit and print the results
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
# Out:
# {'0': 1024}

# %%
from qiskit.visualization import circuit_drawer

circuit_drawer(qc)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
import numpy as np

# Define the logarithmically averaged function
def f(a, g, h, x, m):
    sum = 0
    for n in range(int(x // m), int(x) + 1):
        prod = 1
        for k in range(len(g)):
            prod *= g[k](n + a * h[k])
        sum += prod
    return (1 / np.log(m)) * sum

# Define the values for the function inputs
g = [
    lambda n: np.sin(n),
    lambda n: np.cos(n),
    lambda n: np.tan(n)
]
h = [1, 2, 3]
x = 100
m = 1000

# Choose a value of a for the filter circuit
a = 2

# Create the quantum circuit for signal filtering
qreg = QuantumRegister(1)
creg = ClassicalRegister(1)
qc = QuantumCircuit(qreg, creg)

# Apply the logarithmically averaged filter
for n in range(int(x // m), int(x) + 1):
    qc.rz(f(a, g, h, n, m), qreg[0])

# Measure the filtered signal
qc.measure(qreg[0], creg[0])

# Draw the circuit
print(qc)

# Simulate the circuit and print the results
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
# Out:
#       ┌──────────────┐┌──────────────┐┌─────────────┐┌─────────────┐»
#  q20: ┤ Rz(0.025039) ├┤ Rz(0.030089) ├┤ Rz(0.74538) ├┤ Rz(0.79272) ├»
#       └──────────────┘└──────────────┘└─────────────┘└─────────────┘»
# c8: 1/══════════════════════════════════════════════════════════════»
#                                                                     »
# «      ┌─────────────┐┌────────────┐┌────────────┐┌────────────┐┌────────────┐»
# « q20: ┤ Rz(0.79654) ├┤ Rz(20.377) ├┤ Rz(20.453) ├┤ Rz(20.453) ├┤ Rz(19.972) ├»
# «      └─────────────┘└────────────┘└────────────┘└────────────┘└────────────┘»
# «c8: 1/═══════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «      ┌────────────┐┌────────────┐┌────────────┐┌────────────┐┌────────────┐»
# « q20: ┤ Rz(20.084) ├┤ Rz(20.081) ├┤ Rz(19.919) ├┤ Rz(20.076) ├┤ Rz(20.072) ├»
# ...

# %%
# !pip install mxnet
import numpy as np
from mxnet import autograd, nd, gluon, init
import d2l
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# ...
#   Using cached mxnet-1.9.1-py3-none-manylinux2014_x86_64.whl (49.1 MB)
# ...
#   Using cached graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# ...
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.20.1
#     Uninstalling graphviz-0.20.1:
#       Successfully uninstalled graphviz-0.20.1
# ...
# Traceback (most recent call last):
#   Cell In[5], line 4
#     import d2l
# ModuleNotFoundError: No module named 'd2l'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
import numpy as np

# Define the logarithmically averaged function
def f(a, g, h, x, m):
    sum = 0
    for n in range(int(x // m), int(x) + 1):
        prod = 1
        for k in range(len(g)):
            prod *= g[k](n + a * h[k])
        sum += prod
    return (1 / np.log(m)) * sum

# Define the values for the function inputs
g = [
    lambda n: np.sin(n),
    lambda n: np.cos(n),
    lambda n: np.tan(n)
]
h = [1, 2, 3]
x = 100
m = 1000

# Choose a value of a for the filter circuit
a = 2

# Create the quantum circuit for signal filtering
qreg = QuantumRegister(1)
creg = ClassicalRegister(1)
qc_filter = QuantumCircuit(qreg, creg)

# Apply the logarithmically averaged filter
for n in range(int(x // m), int(x) + 1):
    qc_filter.rz(f(a, g, h, n, m), qreg[0])

# Measure the filtered signal
qc_filter.measure(qreg[0], creg[0])

# Simulate the filtered circuit and print the results
backend = Aer.get_backend('qasm_simulator')
job_filter = execute(qc_filter, backend, shots=1024)
result_filter = job_filter.result()
counts_filter = result_filter.get_counts(qc_filter)
print("Filtered counts:", counts_filter)

# Create the quantum circuit for the unfiltered signal
qc_unfilter = QuantumCircuit(qreg, creg)

# Measure the unfiltered signal
qc_unfilter.measure(qreg[0], creg[0])

# Simulate the unfiltered circuit and print the results
job_unfilter = execute(qc_unfilter, backend, shots=1024)
result_unfilter = job_unfilter.result()
counts_unfilter = result_unfilter.get_counts(qc_unfilter)
print("Unfiltered counts:", counts_unfilter)
# Out:
# Filtered counts: {'0': 1024}
# Unfiltered counts: {'0': 1024}

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
import numpy as np

# Define the logarithmically averaged function
def f(a, g, h, x, m):
    sum = 0
    for n in range(int(x // m), int(x) + 1):
        prod = 1
        for k in range(len(g)):
            prod *= g[k](n + a * h[k])
        sum += prod
    return (1 / np.log(m)) * sum

# Define the values for the function inputs
g = [
    lambda n: np.sin(n),
    lambda n: np.cos(n),
    lambda n: np.tan(n)
]
h = [1, 2, 3]
x = 100
m = 1000

# Choose a value of a for the filter circuit
a = 2

# Create the quantum circuit for signal filtering
qreg = QuantumRegister(1)
creg = ClassicalRegister(1)
qc_filter = QuantumCircuit(qreg, creg)

# Apply the logarithmically averaged filter
for n in range(int(x // m), int(x) + 1):
    qc_filter.rz(f(a, g, h, n, m), qreg[0])

# Measure the filtered signal
qc_filter.measure(qreg[0], creg[0])

# Create the quantum circuit for the unfiltered signal
qc_unfilter = QuantumCircuit(qreg, creg)

# Measure the unfiltered signal
qc_unfilter.measure(qreg[0], creg[0])

# Simulate the filtered and unfiltered circuits with noise
backend = Aer.get_backend('qasm_simulator')
noise_model = NoiseModel.from_backend(backend)
job_filter = execute(qc_filter, backend, shots=1024, noise_model=noise_model)
job_unfilter = execute(qc_unfilter, backend, shots=1024, noise_model=noise_model)
result_filter = job_filter.result()
result_unfilter = job_unfilter.result()

# Get the counts for each circuit
counts_filter = result_filter.get_counts(qc_filter)
counts_unfilter = result_unfilter.get_counts(qc_unfilter)

# Print the results
print("Filtered counts with noise:", counts_filter)
print("Unfiltered counts with noise:", counts_unfilter)
# Out:
# Traceback (most recent call last):
#   Cell In[6], line 47
#     noise_model = NoiseModel.from_backend(backend)
# NameError: name 'NoiseModel' is not defined
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=NameError: name 'NoiseModel' is not defined" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.providers.aer.noise import NoiseModel
import numpy as np

# Define the logarithmically averaged function
def f(a, g, h, x, m):
    sum = 0
    for n in range(int(x // m), int(x) + 1):
        prod = 1
        for k in range(len(g)):
            prod *= g[k](n + a * h[k])
        sum += prod
    return (1 / np.log(m)) * sum

# Define the values for the function inputs
g = [
    lambda n: np.sin(n),
    lambda n: np.cos(n),
    lambda n: np.tan(n)
]
h = [1, 2, 3]
x = 100
m = 1000

# Choose a value of a for the filter circuit
a = 2

# Create the quantum circuit for signal filtering
qreg = QuantumRegister(1)
creg = ClassicalRegister(1)
qc_filter = QuantumCircuit(qreg, creg)

# Apply the logarithmically averaged filter
for n in range(int(x // m), int(x) + 1):
    qc_filter.rz(f(a, g, h, n, m), qreg[0])

# Measure the filtered signal
qc_filter.measure(qreg[0], creg[0])

# Create the quantum circuit for the unfiltered signal
qc_unfilter = QuantumCircuit(qreg, creg)

# Measure the unfiltered signal
qc_unfilter.measure(qreg[0], creg[0])

# Set up a noise model for the simulation
noise_model = NoiseModel.from_backend(backend)
error = 0.1
noise_model.add_all_qubit_quantum_error(lambda p: np.array([[1 - error, error], [error, 1 - error]]), ['u3', 'cx'])

# Simulate the filtered circuit with noise and print the results
backend = Aer.get_backend('qasm_simulator')
job_filter = execute(qc_filter, backend, shots=1024, noise_model=noise_model)
result_filter = job_filter.result()
counts_filter = result_filter.get_counts(qc_filter)
print("Filtered counts with noise:", counts_filter)

# Simulate the unfiltered circuit with noise and print the results
job_unfilter = execute(qc_unfilter, backend, shots=1024, noise_model=noise_model)
result_unfilter = job_unfilter.result()
counts_unfilter = result_unfilter.get_counts(qc_unfilter)
print("Unfiltered counts with noise:", counts_unfilter)
# Out:
# Traceback (most recent call last):
#   Cell In[7], line 47
#     noise_model = NoiseModel.from_backend(backend)
#   File /opt/conda/lib/python3.10/site-packages/qiskit_aer/noise/noise_model.py:342 in from_backend
#     all_qubit_properties = [QubitProperties(t1=properties.t1(q),
#   File /opt/conda/lib/python3.10/site-packages/qiskit_aer/noise/noise_model.py:342 in <listcomp>
#     all_qubit_properties = [QubitProperties(t1=properties.t1(q),
# AttributeError: 'NoneType' object has no attribute 't1'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# ...
