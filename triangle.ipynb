# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# 8-dimensional data
data = [[1, 2, 3, 4, 5, 6, 7, 8], [9, 8, 7, 6, 5, 4, 3, 2], [1, 2, 3, 4, 5, 6, 7, 8], [9, 8, 7, 6, 5, 4, 3, 2]]

# Initialize PCA
pca = PCA(n_components=3)

# Fit and transform data
pca_data = pca.fit_transform(data)

# Visualize data
plt.scatter(pca_data[:, 0], pca_data[:, 1], pca_data[:, 2])
plt.show()

# %%
# !pip install glumpy
# !pip install numpy
# !pip install cython
# !pip install pyopengl
# !pip install triangle
! pip install --upgrade numpy
! pip install --upgrade pyopengl
! pip install --upgrade cython
! pip install --upgrade triangle
# Out:
# ...
#   Using cached numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
#      |████████████████████████████████| 17.3 MB 68 kB/s  eta 0:00:01 |████▎                           | 2.3 MB 1.6 MB/s eta 0:00:10                  | 4.9 MB 1.6 MB/s eta 0:00:08.7 MB 1.6 MB/s eta 0:00:02
# ...
#   Using cached PyOpenGL-3.1.6-py3-none-any.whl (2.4 MB)
#   Using cached PyOpenGL-3.1.5-py3-none-any.whl (2.4 MB)
# ...
#   Using cached Cython-0.29.33-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      |████████████████████████████████| 1.9 MB 1.5 MB/s eta 0:00:01
# ...
#   Using cached triangle-20220202-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#   Using cached triangle-20200424-cp38-cp38-manylinux2010_x86_64.whl (2.0 MB)
# ...

# %%
# !pip install triangle

# %%
import matplotlib.pyplot as plt
import numpy as np

import triangle as tr

A = dict(vertices=np.array(((0, 0), (1, 0), (1, 1), (0, 1))))
B = tr.triangulate(A)
tr.compare(plt, A, B)
plt.show()

# %%
import numpy as np
import triangle as tr
import matplotlib.pyplot as plt

# Define the input points for the seed of life pattern
points = np.array([[0, 0], [1, 0], [1, 1], [0, 1], [0.5, 0.5], [0.5, 0], [0.5, 1], [1, 0.5], [0, 0.5]])

# Use the triangulate function to generate the triangulation
triangulation = tr.triangulate({"vertices": points})

# Plot the triangulation using matplotlib
plt.triplot(points[:, 0], points[:, 1], triangulation["triangles"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import triangle as tr

A = dict(vertices=np.array(((0, 0), (1, 0), (1, 1), (0, 1))))
B = tr.triangulate(A, 'qa0.007')
tr.compare(plt, A, B)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import triangle as tr

N = 32
theta = np.linspace(0, 2 * np.pi, N, endpoint=False)
pts = np.stack([np.cos(theta), np.sin(theta)], axis=1)
A = dict(vertices=pts)
B = tr.triangulate(A, 'q')
tr.compare(plt, A, B)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import triangle as tr

N = 55
theta = np.linspace(0, 2 * np.pi, N, endpoint=False)
pts = np.stack([np.cos(theta), np.sin(theta)], axis=1)
A = dict(vertices=pts)
B = tr.triangulate(A, 'qa0.0314')
tr.compare(plt, A, B)
plt.show()

# %%
import numpy as np
import triangle as tr
import matplotlib.pyplot as plt

# Define the input points for the seed of life pattern
points = np.array([[0, 0], [1, 0], [1, 1], [0, 1], [0.5, 0.5], [0.5, 0], [0.5, 1], [1, 0.5], [0, 0.5]])

# Use the triangulate function to generate the triangulation
triangulation = tr.triangulate({"vertices": points})

# Plot the triangulation using matplotlib
plt.triplot(points[:, 0], points[:, 1], triangulation["triangles"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import triangle as tr

N = 30
phi = (1 + np.sqrt(5)) / 2

fib = [1, 1]
for i in range(2, N):
    fib.append(fib[i-1] + fib[i-2])

theta = np.linspace(0, 2 * np.pi, N, endpoint=False)
r = [fib[i]/max(fib) for i in range(N)]
pts = np.stack([r*np.cos(theta), r*np.sin(theta)], axis=1)
A = dict(vertices=pts)
B = tr.triangulate(A, 'qa0.05')
tr.compare(plt, A, B)
plt.show()

# %%
# !pip install Cython

# %%
import matplotlib.pyplot as plt
import numpy as np
import triangle as tr

def fibonacci(n):
    fibo = []
    for i in range(n): 
        if i == 0 or i == 1:
            fibo.append(i)
        else:
            f = fibo.append(fibo[i-1] + fibo[i-2])
    return fibo

N = 30
phi = (1 + np.sqrt(5)) / 2

fib = fibonacci(N)
fib = [i/max(fib) for i in fib]
theta = np.linspace(0, 2 * np.pi, N, endpoint=False)
r = fib
pts = np.stack([r*np.cos(theta), r*np.sin(theta)], axis=1)
A = dict(vertices=pts)
B = tr.triangulate(A, 'qa0.05')
tr.compare(plt, A, B)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import triangle as tr

def fibonacci(n):
    fibo = []
    for i in range(n): 
        if i == 0 or i == 1:
            fibo.append(i)
        else:
            f = fibo.append(fibo[i-1] + fibo[i-2])
    return fibo

N = 30
phi = (1 + np.sqrt(5)) / 2

fib = fibonacci(N)
fib = [i/max(fib) for i in fib]
theta = np.linspace(0, 2*np.pi, N, endpoint=False)
r = fib
pts = np.stack([r*np.cos(theta), r*np.sin(theta)], axis=1)
A = dict(vertices=pts)
B = tr.triangulate(A, 'qa0.05')
tr.compare(plt, A, B)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import triangle as tr


def circle(N, R):
    i = np.arange(N)
    theta = i * 2 * np.pi / N
    pts = np.stack([np.cos(theta), np.sin(theta)], axis=1) * R
    seg = np.stack([i, i + 1], axis=1) % N
    return pts, seg


pts0, seg0 = circle(30, 1.4)
pts1, seg1 = circle(16, 0.6)
pts = np.vstack([pts0, pts1])
seg = np.vstack([seg0, seg1 + seg0.shape[0]])

A = dict(vertices=pts, segments=seg, holes=[[0, 0]])
B = tr.triangulate(A, 'qpa0.05')
tr.compare(plt, A, B)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import triangle as tr

# arrays to fill in with input
vertices = []
segments = []
regions = []

# make a box with given dims and place given attribute at its center
def make_box(x, y, w, h, attribute):

    i = len(vertices)
    
    vertices.extend([[x,   y],
                     [x+w, y],
                     [x+w, y+h],
                     [x,   y+h]])

    segments.extend([(i+0, i+1),
                     (i+1, i+2),
                     (i+2, i+3),
                     (i+3, i+0)])
    
    regions.append([x+0.5*w, y+0.5*h, attribute, 0])

# generate some input    
make_box(0, 0, 5, 5, 1)
make_box(1, 1, 3, 1, 2)
make_box(1, 3, 1, 1, 3)
make_box(3, 3, 1, 1, 4)

A = dict(vertices=vertices, segments=segments, regions=regions)
B = tr.triangulate(A, 'pA')
    
tr.compare(plt, A, B)
plt.show()

# %%
# !pip install triangle

import matplotlib.pyplot as plt
import numpy as np
import triangle as tr

# arrays to fill in with input
vertices = []
segments = []
regions = []

def fibonacci(n):
    fibo = []
    for i in range(n): 
        if i == 0 or i == 1:
            fibo.append(i)
        else:
            f = fibo.append(fibo[i-1] + fibo[i-2])
    return fibo

# generate some input    
def make_spiral(x, y, r, attribute):
    i = len(vertices)
    N = 30
    fib = fibonacci(N)
    fib = [i/max(fib) for i in fib]
    theta = np.linspace(0, 2*np.pi, N, endpoint=True)
    r = fib
    pts = np.stack([r*np.cos(theta), r*np.sin(theta)], axis=1)
    for i in range(N-1):
        segments.append((i, i+1))
    regions.append([x, y, attribute, 0])
    vertices.extend(pts)

N = 100
make_spiral(0,0,2,1)



A = dict(vertices=vertices, segments=segments, regions=regions)
B = tr.triangulate(A, 'pA')
    
tr.compare(plt, A, B)
plt.show()
# Out:
# ...
#                                               0.0/1.4 MB ? eta -:--:--
#                                               0.0/1.4 MB 1.3 MB/s eta 0:00:02
#                                               0.0/1.4 MB 1.3 MB/s eta 0:00:02
#      ---                                      0.1/1.4 MB 819.2 kB/s eta 0:00:02
#      ---                                      0.1/1.4 MB 654.9 kB/s eta 0:00:02
#      ------                                   0.2/1.4 MB 981.9 kB/s eta 0:00:02
#      -------                                  0.3/1.4 MB 923.9 kB/s eta 0:00:02
#      ----------                               0.4/1.4 MB 1.1 MB/s eta 0:00:01
#      ----------                               0.4/1.4 MB 1.1 MB/s eta 0:00:01
#      -------------                            0.5/1.4 MB 1.2 MB/s eta 0:00:01
#      ------------------                       0.6/1.4 MB 1.4 MB/s eta 0:00:01
#      -----------------------                  0.8/1.4 MB 1.7 MB/s eta 0:00:01
# ...
